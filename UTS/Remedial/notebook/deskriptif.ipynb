# %% [markdown]
# ### Load Data Bersih

# %%
import pandas as pd

df = pd.read_csv('../data/Data_bersih2.csv')
df.head()
# Out:
#    age     sex    bmi  children smoker     region    charges
# 0   19  female  32.67         0    yes  southwest  1688.4924
# 1   18    male  33.77         1     no  southeast  1725.5523
# 2   28    male  33.00         3     no  southeast   444.9462
# 3   33    male  32.67         0     no  northwest  3734.5449
# 4   32    male  28.88         0     no  northwest  3866.8552

# %%
# Melihat Statistik data
df.describe()
# Out:
#                age          bmi     children       charges
# count  1308.000000  1308.000000  1308.000000   1308.000000
# mean     39.071865    32.523119     1.104740   5872.643517
# std      14.007301     4.782002     1.209074   6683.475007
# min      18.000000    15.960000     0.000000      0.124226
# 25%      26.000000    31.540000     0.000000   1633.732450
# 50%      39.000000    32.670000     1.000000   3734.544900
# 75%      51.000000    33.777500     2.000000   6795.357825
# max      64.000000    53.130000     5.000000  33933.563500

# %%
# Mengetes Data dengan shapiro
from scipy.stats import shapiro

for col in df.select_dtypes(include='number'):
    stat, p = shapiro(df[col])
    print(f"{col}: p-value = {p}")
# Out:
# age: p-value = 1.2874319245068159e-21
# bmi: p-value = 1.9356318072502964e-27
# children: p-value = 1.592063606008976e-35
# charges: p-value = 1.4170919789351987e-41

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

for col in df.select_dtypes(include='number'):
    plt.figure(figsize=(10,4))

    # Histogram
    plt.subplot(1,2,1)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribusi {col}')

    # QQ Plot
    plt.subplot(1,2,2)
    stats.probplot(df[col], dist='norm', plot=plt)
    plt.title(f'QQ Plot {col}')

    plt.tight_layout()
    plt.show()
