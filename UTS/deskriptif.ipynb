# %% [markdown]
# ### Load Data

# %%
import pandas as pd

df = pd.read_csv('Data_bersih.csv')
df.head()
# Out:
#   student_id  hours_studied  sleep_hours  attendance_percent  previous_scores  \
# 0       S001           11.4          4.5                60.9             67.0
# 1       S002            4.4          6.3                74.8             68.0
# 2       S003           10.3          5.5                59.1             79.0
# 3       S004            3.4          5.3                90.9             81.0
# 4       S005           11.9          8.4                53.9             78.0
#
#    exam_score
# 0        40.8
# 1        35.0
# 2        42.1
# 3        29.3
# 4        48.6

# %%
df.describe()
# Out:
#        hours_studied  sleep_hours  attendance_percent  previous_scores  \
# count      250.00000   250.000000          250.000000       250.000000
# mean         6.21880     6.560200           75.624950        66.568000
# std          3.20751     1.490218           14.527628        15.160632
# min          0.50000     1.650000           24.337500        40.000000
# 25%          3.60000     5.400000           62.700000        54.000000
# 50%          5.90000     6.600000           77.000000        67.000000
# 75%          8.80000     7.900000           88.275000        79.000000
# max         16.60000     9.000000          100.000000        95.000000
#
#        exam_score
# count  250.000000
# mean    33.825250
# std      6.695303
# min     16.737500
# 25%     29.600000
# 50%     34.200000
# 75%     38.175000
# max     51.037500

# %%
from scipy.stats import shapiro

for col in df.select_dtypes(include='number'):
    stat, p = shapiro(df[col])
    print(f"{col}: p-value = {p}")
# Out:
# hours_studied: p-value = 2.3370019204576278e-06
# sleep_hours: p-value = 5.352252522305057e-07
# attendance_percent: p-value = 6.1736306991381e-07
# previous_scores: p-value = 8.678010748851226e-07
# exam_score: p-value = 0.8059784176896412

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

for col in df.select_dtypes(include='number'):
    plt.figure(figsize=(10,4))

    # Histogram
    plt.subplot(1,2,1)
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribusi {col}')

    # QQ Plot
    plt.subplot(1,2,2)
    stats.probplot(df[col], dist='norm', plot=plt)
    plt.title(f'QQ Plot {col}')

    plt.tight_layout()
    plt.show()
